# %%
from git import Repo

repo = Repo("../.")

branch = repo.active_branch.name
commits = list(repo.iter_commits(branch))


# diff
diff = repo.git.diff()

# staged diff
staged_diff = repo.git.diff("--cached")

for commit in commits:
    print(f"Commit: {commit.hexsha}")
    print(f"Author: {commit.author.name} <{commit.author.email}>")
    print(f"Date: {commit.committed_datetime}")
    print(f"Message: {commit.message}")
    print(f"diff: {commit.diff}")
    print("-" * 40)
# Out:
# Commit: 6d77ad796d5da19b3e1beab90e63c605221c2e72
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-18 18:00:13+09:00
# Message: delete sessions
#
# diff: <bound method Diffable.diff of <git.Commit "6d77ad796d5da19b3e1beab90e63c605221c2e72">>
# ----------------------------------------
# Commit: db4c0fa00c6da4acb2e55dced0679b56924f2411
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-18 17:58:52+09:00
# Message: d23 story book maker: basic pipeline
#
# diff: <bound method Diffable.diff of <git.Commit "db4c0fa00c6da4acb2e55dced0679b56924f2411">>
# ----------------------------------------
# Commit: 4cc52cd7b9c7534e5b1554bf04aa82b5387eb725
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-16 17:14:04+09:00
# Message: 유저 메세지 저장 방식 변경
#
# diff: <bound method Diffable.diff of <git.Commit "4cc52cd7b9c7534e5b1554bf04aa82b5387eb725">>
# ----------------------------------------
# Commit: b7b12254316cd4163b1e453296a92a475fcd66e7
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 14:57:29+09:00
# Message: +
#
# diff: <bound method Diffable.diff of <git.Commit "b7b12254316cd4163b1e453296a92a475fcd66e7">>
# ----------------------------------------
# Commit: fb3e3235004936dba356f6ae4655a3faa1ae6f90
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 14:54:50+09:00
# Message: child -> parent, handoff 추가
#
# diff: <bound method Diffable.diff of <git.Commit "fb3e3235004936dba356f6ae4655a3faa1ae6f90">>
# ----------------------------------------
# Commit: ee44039894072b28344e8145391628c03b67dadc
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 14:19:29+09:00
# Message: 경고 ui 위치 조정git push
#
# diff: <bound method Diffable.diff of <git.Commit "ee44039894072b28344e8145391628c03b67dadc">>
# ----------------------------------------
# Commit: 20926884f72fea54cebcd87cd04c3c82d5d20676
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 14:18:00+09:00
# Message: apk_key 입력 할수 있도록 추가
#
# diff: <bound method Diffable.diff of <git.Commit "20926884f72fea54cebcd87cd04c3c82d5d20676">>
# ----------------------------------------
# Commit: ece8f18a5107cd148731f055d760a31121ca3eeb
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 14:05:46+09:00
# Message: 코드 정리
#
# diff: <bound method Diffable.diff of <git.Commit "ece8f18a5107cd148731f055d760a31121ca3eeb">>
# ----------------------------------------
# Commit: e05c81f964eec3eefc2b952fd00758323a2ed6c5
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 13:57:53+09:00
# Message: session id cookie 에 저장
#
# diff: <bound method Diffable.diff of <git.Commit "e05c81f964eec3eefc2b952fd00758323a2ed6c5">>
# ----------------------------------------
# Commit: 3124b0e00f353634e73f996d46aed4f30e50fb69
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-15 13:33:53+09:00
# Message: streamlit deploy
#
# diff: <bound method Diffable.diff of <git.Commit "3124b0e00f353634e73f996d46aed4f30e50fb69">>
# ----------------------------------------
# Commit: a1849207d7897177beeba1d62b3c22d262c7ce78
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-11 23:15:04+09:00
# Message: d17 Restaurant Bot: Guardrails & Complaints
#
# diff: <bound method Diffable.diff of <git.Commit "a1849207d7897177beeba1d62b3c22d262c7ce78">>
# ----------------------------------------
# Commit: 10a3dc2d3c3a5d2a569e63b4fca07276fe55f9b3
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-10 22:50:34+09:00
# Message: d16 restaurant bot:handoffs
#
# diff: <bound method Diffable.diff of <git.Commit "10a3dc2d3c3a5d2a569e63b4fca07276fe55f9b3">>
# ----------------------------------------
# Commit: 617fe6b8f111ff77641488e0dcc5190871b9a46a
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-06 17:23:24+09:00
# Message: 아바타 이미지 변경
#
# diff: <bound method Diffable.diff of <git.Commit "617fe6b8f111ff77641488e0dcc5190871b9a46a">>
# ----------------------------------------
# Commit: 968081bf4c4c472a769d7d33f2bf155448d0b864
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-05 22:04:34+09:00
# Message: d11 life coach: Vision Boards 기초
#
# diff: <bound method Diffable.diff of <git.Commit "968081bf4c4c472a769d7d33f2bf155448d0b864">>
# ----------------------------------------
# Commit: 222a78c18e8cca2cbb141c3a910e295c0718a4ee
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-04 22:18:57+09:00
# Message: d10 life coach: file search
#
# diff: <bound method Diffable.diff of <git.Commit "222a78c18e8cca2cbb141c3a910e295c0718a4ee">>
# ----------------------------------------
# Commit: 5bb722d67ad19c961a8553072f06e109f71e779e
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-03 18:12:12+09:00
# Message: add .DS_Store to .gitignore
#
# diff: <bound method Diffable.diff of <git.Commit "5bb722d67ad19c961a8553072f06e109f71e779e">>
# ----------------------------------------
# Commit: 0d33a1a5829fd85eb06194b0ed82b0424047230d
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-03-03 18:10:49+09:00
# Message: d09 life coach:web search
#
# diff: <bound method Diffable.diff of <git.Commit "0d33a1a5829fd85eb06194b0ed82b0424047230d">>
# ----------------------------------------
# Commit: 1b8aa71f003fe0c5071c64adc22291cc5e7a91ae
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-02-28 07:26:54+09:00
# Message: d05 The Complete Agentic Loop: Movie Agent
#
# diff: <bound method Diffable.diff of <git.Commit "1b8aa71f003fe0c5071c64adc22291cc5e7a91ae">>
# ----------------------------------------
# Commit: 415a34d6bfdb1d89e1c0d1e4ee10403a74cc07b2
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-02-25 06:47:00+09:00
# Message: d03 Movie Recommendation Bot with Memory
#
# diff: <bound method Diffable.diff of <git.Commit "415a34d6bfdb1d89e1c0d1e4ee10403a74cc07b2">>
# ----------------------------------------
# Commit: 07f4e975aeb7af1e0fd36d12d30b1f41494dd2f8
# Author: topcircle <topcircle@gmail.com>
# Date: 2026-02-24 16:51:47+09:00
# Message: d02 movie expert agent
#
# diff: <bound method Diffable.diff of <git.Commit "07f4e975aeb7af1e0fd36d12d30b1f41494dd2f8">>
# ----------------------------------------
